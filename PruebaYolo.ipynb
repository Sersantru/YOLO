# %% [markdown]
# <a href="https://colab.research.google.com/github/Sersantru/YOLO/blob/main/PruebaYolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="OSfKHYrzNBpG0shXaTqs")
project = rf.workspace("sergios-workspace-tyauk").project("humandogsimple")
dataset = project.version(1).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
from ultralytics import YOLO
# Out:
# Ultralytics 8.4.30 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.9/112.6 GB disk)

# %%
model=YOLO('yolov8n.pt')

# %%
# !yolo detect train model=yolov8n.pt data=/content/HumandogSimple-1/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.4.30 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
resultados = model.predict(source='https://ultralytics.com/images/zidane.jpg', save=True)
# Out:
# ...
# image 1/1 /content/zidane.jpg: 384x640 2 persons, 1 tie, 78.1ms
# Speed: 6.5ms preprocess, 78.1ms inference, 22.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/runs/detect/predict

# %%
import cv2
from google.colab.patches import cv2_imshow

# Por defecto, Ultralytics guarda las predicciones en esta ruta
ruta_imagen = 'runs/detect/predict/zidane.jpg'

imagen = cv2.imread(ruta_imagen)
cv2_imshow(imagen)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>
